# %%
import pandas as pd
import numpy as np

# %%
files = ['MOCK_DATA (1).csv','MOCK_DATA (2).csv',
        'MOCK_DATA (3).csv','MOCK_DATA (4).csv','MOCK_DATA (5).csv',
         'MOCK_DATA (6).csv','MOCK_DATA (7).csv','MOCK_DATA (8).csv','MOCK_DATA (9).csv']

# %%
df = pd.read_csv('MOCK_DATA.csv')

for file in files:
    df1 = pd.read_csv(file)
    df = pd.concat([df,df1],ignore_index=True)

# %%
df
# Out:
#       order_id  customer_id  restaurant_id           order_time  \
# 0         9813         7032            342  2024-04-06 00:00:00
# 1         9381         8269            541  2024-04-06 00:00:00
# 2         7804         3693            499  2024-04-06 00:00:00
# 3         7726         2171            174  2024-04-06 00:00:00
# 4         6719         1937            165  2024-04-06 00:00:00
# ...        ...          ...            ...                  ...
# 9995      7545         9839            698  2024-04-06 00:00:00
# 9996      1740         9131            740  2024-04-06 00:00:00
# 9997      5226         1150            725  2024-04-06 00:00:00
# 9998      7161         4813            111  2024-04-06 00:00:00
# 9999      3169         7594            238  2024-04-06 00:00:00
#
#      customer_location restaurant_location  order_value  rating
# 0           15th Floor            Suite 31      1810.20    0.55
# 1             Room 386            Room 126       157.01    4.63
# ...

# %%
time = pd.to_timedelta(np.random.randint(0,60*60*22,size=len(df)),unit='s')

# %%
df['order_time']=pd.to_datetime(df['order_time']).add(time)

# %%
df
# Out:
#       order_id  customer_id  restaurant_id          order_time  \
# 0         9813         7032            342 2024-04-06 15:34:13
# 1         9381         8269            541 2024-04-06 12:43:05
# 2         7804         3693            499 2024-04-06 14:54:41
# 3         7726         2171            174 2024-04-06 01:22:50
# 4         6719         1937            165 2024-04-06 10:04:25
# ...        ...          ...            ...                 ...
# 9995      7545         9839            698 2024-04-06 21:19:05
# 9996      1740         9131            740 2024-04-06 10:52:32
# 9997      5226         1150            725 2024-04-06 15:44:08
# 9998      7161         4813            111 2024-04-06 03:14:24
# 9999      3169         7594            238 2024-04-06 19:27:11
#
#      customer_location restaurant_location  order_value  rating
# 0           15th Floor            Suite 31      1810.20    0.55
# 1             Room 386            Room 126       157.01    4.63
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             10000 non-null  int64
#  1   customer_id          10000 non-null  int64
#  2   restaurant_id        10000 non-null  int64
#  3   order_time           10000 non-null  datetime64[ns]
#  4   customer_location    10000 non-null  object
#  5   restaurant_location  10000 non-null  object
#  6   order_value          10000 non-null  float64
#  7   rating               10000 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 625.1+ KB

# %%
del_time = pd.to_timedelta(np.random.randint(0,60*60,size = len(df)),unit='s')
df['delivery_time']=df['order_time'].add(del_time)

# %%
df
# Out:
#       order_id  customer_id  restaurant_id          order_time  \
# 0         9813         7032            342 2024-04-06 15:34:13
# 1         9381         8269            541 2024-04-06 12:43:05
# 2         7804         3693            499 2024-04-06 14:54:41
# 3         7726         2171            174 2024-04-06 01:22:50
# 4         6719         1937            165 2024-04-06 10:04:25
# ...        ...          ...            ...                 ...
# 9995      7545         9839            698 2024-04-06 21:19:05
# 9996      1740         9131            740 2024-04-06 10:52:32
# 9997      5226         1150            725 2024-04-06 15:44:08
# 9998      7161         4813            111 2024-04-06 03:14:24
# 9999      3169         7594            238 2024-04-06 19:27:11
#
#      customer_location restaurant_location  order_value  rating  \
# 0           15th Floor            Suite 31      1810.20    0.55
# 1             Room 386            Room 126       157.01    4.63
# ...

# %%
df.to_csv('Orders_data.csv', index=False)
